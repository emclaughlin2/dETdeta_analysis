# %%
import ROOT
from ROOT import TCanvas, TFile, TProfile, TNtuple, TH1I, TH1F, TH2F, TH3F, TColor, TEfficiency
from ROOT import gROOT, gBenchmark, gRandom, gSystem
import numpy as np
import pdb

# %%
# %cd /sphenix/u/egm2153/spring_2023
gROOT.LoadMacro("sPhenixStyle.C");
gROOT.ProcessLine("SetsPhenixStyle()")
# Out:
# /direct/sphenix+u/egm2153/spring_2023
# 0
# sPhenixStyle: Applying nominal settings.
# sPhenixStyle: ROOT6 mode

# %%
# %cd /sphenix/user/egm2153/calib_study/detdeta/analysis/runs23727_23746
# %ls *p011*
# Out:
# /gpfs/mnt/gpfs02/sphenix/user/egm2153/calib_study/detdeta/analysis/runs23727_23746
# dETdeta_analysis_23727_z=0_p011_centbin_zs_30ADC_data_noweight_0-4.root
# dETdeta_analysis_23727_z=0_p011_centbin_zs_30ADC_data_noweight_0-5.root
# dETdeta_analysis_23727_z=0_p011_centbin_zs_30ADC_data_noweight_0-6.root
# dETdeta_analysis_23727_z=0_p011_nozs_data_noweight_0-90.root
# dETdeta_analysis_23727_z=0_p011_nozs_mc_reweight_0-5_ampt.root
# dETdeta_analysis_23727_z=0_p011_nozs_mc_reweight_0-5_epos.root
# dETdeta_analysis_23727_z=0_p011_nozs_mc_reweight_0-5_hijing.root
# dETdeta_analysis_23727_z=0_p011_zs_10ADC_data_noweight_0-90.root
# dETdeta_analysis_23727_z=0_p011_zs_20ADC_data_noweight_0-90.root
# dETdeta_analysis_23727_z=0_p011_zs_30ADC_data_noweight_0-10.root
# dETdeta_analysis_23727_z=0_p011_zs_30ADC_data_noweight_0-90.root
# dETdeta_analysis_23727_z=0_p011_zs_40ADC_data_noweight_0-90.root
# dETdeta_analysis_23727_z=0_p011_zs_50ADC_data_noweight_0-90.root
# ...

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC
f1 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_30ADC_data_noweight_0-90.root")
h_eT_sim_emcal = TH1F(f1.Get("h_eT_emcal"))
h_eT_sim_ihcal = TH1F(f1.Get("h_eT_ihcal"))
h_eT_sim_ohcal = TH1F(f1.Get("h_eT_ohcal"))
h_eT_sim_emcal.SetDirectory(0)
h_eT_sim_ihcal.SetDirectory(0)
h_eT_sim_ohcal.SetDirectory(0)
f1.Close()
f2 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_20ADC_data_noweight_0-90.root")
h_eT_data_emcal = TH1F(f2.Get("h_eT_emcal"))
h_eT_data_ihcal = TH1F(f2.Get("h_eT_ihcal"))
h_eT_data_ohcal = TH1F(f2.Get("h_eT_ohcal"))
h_eT_data_emcal.SetDirectory(0)
h_eT_data_ihcal.SetDirectory(0)
h_eT_data_ohcal.SetDirectory(0)
f2.Close()
f3 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_10ADC_data_noweight_0-90.root")
h_eT_epos_emcal = TH1F(f3.Get("h_eT_emcal"))
h_eT_epos_ihcal = TH1F(f3.Get("h_eT_ihcal"))
h_eT_epos_ohcal = TH1F(f3.Get("h_eT_ohcal"))
h_eT_epos_emcal.SetDirectory(0)
h_eT_epos_ihcal.SetDirectory(0)
h_eT_epos_ohcal.SetDirectory(0)
f3.Close()
f4 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_40ADC_data_noweight_0-90.root")
h_eT_ampt_emcal = TH1F(f4.Get("h_eT_emcal"))
h_eT_ampt_ihcal = TH1F(f4.Get("h_eT_ihcal"))
h_eT_ampt_ohcal = TH1F(f4.Get("h_eT_ohcal"))
h_eT_ampt_emcal.SetDirectory(0)
h_eT_ampt_ihcal.SetDirectory(0)
h_eT_ampt_ohcal.SetDirectory(0)
f4.Close()
f5 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_50ADC_data_noweight_0-90.root")
h_eT_sim1_emcal = TH1F(f5.Get("h_eT_emcal"))
h_eT_sim1_ihcal = TH1F(f5.Get("h_eT_ihcal"))
h_eT_sim1_ohcal = TH1F(f5.Get("h_eT_ohcal"))
h_eT_sim1_emcal.SetDirectory(0)
h_eT_sim1_ihcal.SetDirectory(0)
h_eT_sim1_ohcal.SetDirectory(0)
f5.Close()
f6 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p008_nozs_data_noweight_0-90.root")
h_eT_data1_emcal = TH1F(f6.Get("h_eT_emcal"))
h_eT_data1_ihcal = TH1F(f6.Get("h_eT_ihcal"))
h_eT_data1_ohcal = TH1F(f6.Get("h_eT_ohcal"))
h_eT_data1_emcal.SetDirectory(0)
h_eT_data1_ihcal.SetDirectory(0)
h_eT_data1_ohcal.SetDirectory(0)
f6.Close()

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.18,.6,.55)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(h_eT_epos_emcal,"10 ADC ZS","lep")
leg.AddEntry(h_eT_data_emcal,"20 ADC ZS","lep")
leg.AddEntry(h_eT_sim_emcal,"30 ADC ZS","lep")
leg.AddEntry(h_eT_ampt_emcal,"40 ADC ZS","lep")
leg.AddEntry(h_eT_sim1_emcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_emcal.SetStats(0)
h_eT_sim_emcal.SetStats(0)
h_eT_sim1_emcal.SetStats(0)
h_eT_epos_emcal.SetStats(0)
h_eT_ampt_emcal.SetStats(0)
h_eT_data_emcal.SetYTitle("EMCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_emcal.SetXTitle("#eta")
h_eT_data_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_emcal.GetYaxis().SetRangeUser(0,230)
h_eT_sim_emcal.GetYaxis().SetRangeUser(0,230)
h_eT_sim1_emcal.GetYaxis().SetRangeUser(0,230)
h_eT_epos_emcal.GetYaxis().SetRangeUser(0,230)
h_eT_ampt_emcal.GetYaxis().SetRangeUser(0,230)
h_eT_data_emcal.SetLineColor(1)
h_eT_sim_emcal.SetLineColor(6)
h_eT_epos_emcal.SetLineColor(2)
h_eT_ampt_emcal.SetLineColor(3)
h_eT_sim1_emcal.SetLineColor(4)
h_eT_data_emcal.SetMarkerColor(1)
h_eT_sim_emcal.SetMarkerColor(6)
h_eT_epos_emcal.SetMarkerColor(2)
h_eT_ampt_emcal.SetMarkerColor(3)
h_eT_sim1_emcal.SetMarkerColor(4)
h_eT_data_emcal.Draw()
h_eT_ampt_emcal.Draw('same')
h_eT_sim_emcal.Draw('same')
h_eT_sim1_emcal.Draw('same')
h_eT_epos_emcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/emcal_reco_zs_nocrosscalib.png')
# Out:
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/emcal_reco_zs_nocrosscalib.png has been created

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.28,.58,.6,.85)
leg.AddEntry("","Run 23727-p011 MB","")
leg.AddEntry(h_eT_epos_ihcal,"10 ADC ZS","lep")
leg.AddEntry(h_eT_data_ihcal,"20 ADC ZS","lep")
leg.AddEntry(h_eT_sim_ihcal,"30 ADC ZS","lep")
leg.AddEntry(h_eT_ampt_ihcal,"40 ADC ZS","lep")
leg.AddEntry(h_eT_sim1_ihcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_ihcal.SetStats(0)
h_eT_sim_ihcal.SetStats(0)
h_eT_sim1_ihcal.SetStats(0)
h_eT_epos_ihcal.SetStats(0)
h_eT_ampt_ihcal.SetStats(0)
h_eT_data_ihcal.SetYTitle("IHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ihcal.SetXTitle("#eta")
h_eT_data_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_sim_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_sim1_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_epos_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_ampt_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_data_ihcal.SetLineColor(1)
h_eT_sim_ihcal.SetLineColor(6)
h_eT_epos_ihcal.SetLineColor(2)
h_eT_ampt_ihcal.SetLineColor(3)
h_eT_sim1_ihcal.SetLineColor(4)
h_eT_data_ihcal.SetMarkerColor(1)
h_eT_sim_ihcal.SetMarkerColor(6)
h_eT_epos_ihcal.SetMarkerColor(2)
h_eT_ampt_ihcal.SetMarkerColor(3)
h_eT_sim1_ihcal.SetMarkerColor(4)
h_eT_data_ihcal.Draw()
h_eT_ampt_ihcal.Draw('same')
h_eT_sim_ihcal.Draw('same')
h_eT_sim1_ihcal.Draw('same')
h_eT_epos_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ihcal_reco_zs_nocrosscalib.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/ihcal_reco_zs_nocrosscalib.png has been created

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.28,.58,.6,.85)
leg.AddEntry("","Run 23727-p011 MB","")
leg.AddEntry(h_eT_epos_ohcal,"10 ADC ZS","lep")
leg.AddEntry(h_eT_data_ohcal,"20 ADC ZS","lep")
leg.AddEntry(h_eT_sim_ohcal,"30 ADC ZS","lep")
leg.AddEntry(h_eT_ampt_ohcal,"40 ADC ZS","lep")
leg.AddEntry(h_eT_sim1_ohcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_ohcal.SetStats(0)
h_eT_sim_ohcal.SetStats(0)
h_eT_sim1_ohcal.SetStats(0)
h_eT_epos_ohcal.SetStats(0)
h_eT_ampt_ohcal.SetStats(0)
h_eT_data_ohcal.SetYTitle("OHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ohcal.SetXTitle("#eta")
h_eT_data_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_sim_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_sim1_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_epos_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_ampt_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_data_ohcal.SetLineColor(1)
h_eT_sim_ohcal.SetLineColor(6)
h_eT_epos_ohcal.SetLineColor(2)
h_eT_ampt_ohcal.SetLineColor(3)
h_eT_sim1_ohcal.SetLineColor(4)
h_eT_data_ohcal.SetMarkerColor(1)
h_eT_sim_ohcal.SetMarkerColor(6)
h_eT_epos_ohcal.SetMarkerColor(2)
h_eT_ampt_ohcal.SetMarkerColor(3)
h_eT_sim1_ohcal.SetMarkerColor(4)
h_eT_data_ohcal.Draw()
h_eT_ampt_ohcal.Draw('same')
h_eT_sim_ohcal.Draw('same')
h_eT_sim1_ohcal.Draw('same')
h_eT_epos_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ohcal_reco_zs_nocrosscalib.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/ohcal_reco_zs_nocrosscalib.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

timing = TH1F(h_eT_sim1_emcal.Clone("timing"))
timing.Divide(h_eT_data_emcal)
energy = TH1F(h_eT_sim_emcal.Clone("energy"))
energy.Divide(h_eT_data_emcal)
both = TH1F(h_eT_data1_emcal.Clone("both"))
both.Divide(h_eT_data_emcal)
both1 = TH1F(h_eT_epos_emcal.Clone("both1"))
both1.Divide(h_eT_data_emcal)
both2 = TH1F(h_eT_ampt_emcal.Clone("both2"))
both2.Divide(h_eT_data_emcal)
both3 = TH1F(h_eT_data2_emcal.Clone("both3"))
both3.Divide(h_eT_data_emcal)
both4 = TH1F(h_eT_data3_emcal.Clone("both4"))
both4.Divide(h_eT_data_emcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.55,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both1,"10 ADC ZS / NO ZS","lep")
leg.AddEntry(both2,"15 ADC ZS / NO ZS","lep")
leg.AddEntry(timing,"20 ADC ZS / NO ZS","lep")
leg.AddEntry(both,"25 ADC ZS / NO ZS","lep")
leg.AddEntry(energy,"30 ADC ZS / NO ZS","lep")
leg.AddEntry(both3,"40 ADC ZS / NO ZS","lep")
leg.AddEntry(both4,"50 ADC ZS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(6)
energy.SetMarkerColor(6)
both.SetLineColor(7)
both.SetMarkerColor(7)
both1.SetLineColor(2)
both1.SetMarkerColor(2)
both2.SetLineColor(3)
both2.SetMarkerColor(3)
timing.SetLineColor(4)
timing.SetMarkerColor(4)
both3.SetLineColor(8)
both3.SetMarkerColor(8)
both4.SetLineColor(11)
both4.SetMarkerColor(11)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
both1.SetStats(0)
both2.SetStats(0)
both3.SetStats(0)
both4.SetStats(0)
energy.GetYaxis().SetRangeUser(0.7,1.3)
both.GetYaxis().SetRangeUser(0.7,1.3)
both1.GetYaxis().SetRangeUser(0.7,1.3)
both2.GetYaxis().SetRangeUser(0.7,1.3)
both3.GetYaxis().SetRangeUser(0.7,1.3)
both4.GetYaxis().SetRangeUser(0.7,1.3)
timing.GetYaxis().SetRangeUser(0.7,1.3)
energy.SetYTitle('Reco EMCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
both1.Draw('same')
both2.Draw('same')
timing.Draw('same')
both3.Draw('same')
both4.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/emcal_reco_zs_nocrosscalib_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/emcal_reco_zs_nocrosscalib_ratio.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

timing = TH1F(h_eT_sim1_ihcal.Clone("timing"))
timing.Divide(h_eT_data_ihcal)
energy = TH1F(h_eT_sim_ihcal.Clone("energy"))
energy.Divide(h_eT_data_ihcal)
both = TH1F(h_eT_data1_ihcal.Clone("both"))
both.Divide(h_eT_data_ihcal)
both1 = TH1F(h_eT_epos_ihcal.Clone("both1"))
both1.Divide(h_eT_data_ihcal)
both2 = TH1F(h_eT_ampt_ihcal.Clone("both2"))
both2.Divide(h_eT_data_ihcal)
both3 = TH1F(h_eT_data2_ihcal.Clone("both3"))
both3.Divide(h_eT_data_ihcal)
both4 = TH1F(h_eT_data3_ihcal.Clone("both4"))
both4.Divide(h_eT_data_ihcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.55,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both1,"10 ADC ZS / NO ZS","lep")
leg.AddEntry(both2,"15 ADC ZS / NO ZS","lep")
leg.AddEntry(timing,"20 ADC ZS / NO ZS","lep")
leg.AddEntry(both,"25 ADC ZS / NO ZS","lep")
leg.AddEntry(energy,"30 ADC ZS / NO ZS","lep")
leg.AddEntry(both3,"40 ADC ZS / NO ZS","lep")
leg.AddEntry(both4,"50 ADC ZS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(6)
energy.SetMarkerColor(6)
both.SetLineColor(7)
both.SetMarkerColor(7)
both1.SetLineColor(2)
both1.SetMarkerColor(2)
both2.SetLineColor(3)
both2.SetMarkerColor(3)
timing.SetLineColor(4)
timing.SetMarkerColor(4)
both3.SetLineColor(8)
both3.SetMarkerColor(8)
both4.SetLineColor(11)
both4.SetMarkerColor(11)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
both1.SetStats(0)
both2.SetStats(0)
both3.SetStats(0)
both4.SetStats(0)
energy.GetYaxis().SetRangeUser(0.95,1.05)
both.GetYaxis().SetRangeUser(0.95,1.05)
both1.GetYaxis().SetRangeUser(0.95,1.05)
both2.GetYaxis().SetRangeUser(0.95,1.05)
both3.GetYaxis().SetRangeUser(0.95,1.05)
both4.GetYaxis().SetRangeUser(0.95,1.05)
timing.GetYaxis().SetRangeUser(0.95,1.05)
energy.SetYTitle('Reco IHCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
both1.Draw('same')
both2.Draw('same')
timing.Draw('same')
both3.Draw('same')
both4.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/ihcal_reco_zs_nocrosscalib_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/ihcal_reco_zs_nocrosscalib_ratio.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

timing = TH1F(h_eT_sim1_ohcal.Clone("timing"))
timing.Divide(h_eT_data_ohcal)
energy = TH1F(h_eT_sim_ohcal.Clone("energy"))
energy.Divide(h_eT_data_ohcal)
both = TH1F(h_eT_data1_ohcal.Clone("both"))
both.Divide(h_eT_data_ohcal)
both1 = TH1F(h_eT_epos_ohcal.Clone("both1"))
both1.Divide(h_eT_data_ohcal)
both2 = TH1F(h_eT_ampt_ohcal.Clone("both2"))
both2.Divide(h_eT_data_ohcal)
both3 = TH1F(h_eT_data2_ohcal.Clone("both3"))
both3.Divide(h_eT_data_ohcal)
both4 = TH1F(h_eT_data3_ohcal.Clone("both4"))
both4.Divide(h_eT_data_ohcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.2,.58,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both1,"10 ADC ZS / NO ZS","lep")
leg.AddEntry(both2,"15 ADC ZS / NO ZS","lep")
leg.AddEntry(timing,"20 ADC ZS / NO ZS","lep")
leg.AddEntry(both,"25 ADC ZS / NO ZS","lep")
leg.AddEntry(energy,"30 ADC ZS / NO ZS","lep")
leg.AddEntry(both3,"40 ADC ZS / NO ZS","lep")
leg.AddEntry(both4,"50 ADC ZS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(6)
energy.SetMarkerColor(6)
both.SetLineColor(7)
both.SetMarkerColor(7)
both1.SetLineColor(2)
both1.SetMarkerColor(2)
both2.SetLineColor(3)
both2.SetMarkerColor(3)
timing.SetLineColor(4)
timing.SetMarkerColor(4)
both3.SetLineColor(8)
both3.SetMarkerColor(8)
both4.SetLineColor(11)
both4.SetMarkerColor(11)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
both1.SetStats(0)
both2.SetStats(0)
both3.SetStats(0)
both4.SetStats(0)
energy.GetYaxis().SetRangeUser(0.9,1.1)
both.GetYaxis().SetRangeUser(0.9,1.1)
both1.GetYaxis().SetRangeUser(0.9,1.1)
both2.GetYaxis().SetRangeUser(0.9,1.1)
both3.GetYaxis().SetRangeUser(0.9,1.1)
both4.GetYaxis().SetRangeUser(0.9,1.1)
timing.GetYaxis().SetRangeUser(0.9,1.1)
energy.SetYTitle('Reco OHCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
both1.Draw('same')
both2.Draw('same')
timing.Draw('same')
both3.Draw('same')
both4.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/ohcal_reco_zs_nocrosscalib_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/ohcal_reco_zs_nocrosscalib_ratio.png has been created

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC
f1 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_30ADC_data_noweight_0-90.root")
h_sim_emcal = TH1F(f1.Get("h_event_emcal_energy"))
h_sim_emcal.SetDirectory(0)
h_sim_ihcal = TH1F(f1.Get("h_event_ihcal_energy"))
h_sim_ihcal.SetDirectory(0)
h_sim_ohcal = TH1F(f1.Get("h_event_ohcal_energy"))
h_sim_ohcal.SetDirectory(0)
h_eT_sim_emcal = TH1F(f1.Get("h_eT_emcal"))
h_eT_sim_emcal.SetDirectory(0)
h_eT_sim_ihcal = TH1F(f1.Get("h_eT_ihcal"))
h_eT_sim_ihcal.SetDirectory(0)
h_eT_sim_ohcal = TH1F(f1.Get("h_eT_ohcal"))
h_eT_sim_ohcal.SetDirectory(0)
f1.Close()
f2 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_20ADC_data_noweight_0-90.root")
h_data_emcal = TH1F(f2.Get("h_event_emcal_energy"))
h_data_emcal.SetDirectory(0)
h_data_ihcal = TH1F(f2.Get("h_event_ihcal_energy"))
h_data_ihcal.SetDirectory(0)
h_data_ohcal = TH1F(f2.Get("h_event_ohcal_energy"))
h_data_ohcal.SetDirectory(0)
h_eT_data_emcal = TH1F(f2.Get("h_eT_emcal"))
h_eT_data_emcal.SetDirectory(0)
h_eT_data_ihcal = TH1F(f2.Get("h_eT_ihcal"))
h_eT_data_ihcal.SetDirectory(0)
h_eT_data_ohcal = TH1F(f2.Get("h_eT_ohcal"))
h_eT_data_ohcal.SetDirectory(0)
f2.Close()
f3 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_10ADC_data_noweight_0-90.root")
h_epos_emcal = TH1F(f3.Get("h_event_emcal_energy"))
h_epos_emcal.SetDirectory(0)
h_epos_ihcal = TH1F(f3.Get("h_event_ihcal_energy"))
h_epos_ihcal.SetDirectory(0)
h_epos_ohcal = TH1F(f3.Get("h_event_ohcal_energy"))
h_epos_ohcal.SetDirectory(0)
h_eT_epos_emcal = TH1F(f3.Get("h_eT_emcal"))
h_eT_epos_emcal.SetDirectory(0)
h_eT_epos_ihcal = TH1F(f3.Get("h_eT_ihcal"))
h_eT_epos_ihcal.SetDirectory(0)
h_eT_epos_ohcal = TH1F(f3.Get("h_eT_ohcal"))
h_eT_epos_ohcal.SetDirectory(0)
f3.Close()
f4 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_40ADC_data_noweight_0-90.root")
h_ampt_emcal = TH1F(f4.Get("h_event_emcal_energy"))
h_ampt_emcal.SetDirectory(0)
h_ampt_ihcal = TH1F(f4.Get("h_event_ihcal_energy"))
h_ampt_ihcal.SetDirectory(0)
h_ampt_ohcal = TH1F(f4.Get("h_event_ohcal_energy"))
h_ampt_ohcal.SetDirectory(0)
h_eT_ampt_emcal = TH1F(f4.Get("h_eT_emcal"))
h_eT_ampt_emcal.SetDirectory(0)
h_eT_ampt_ihcal = TH1F(f4.Get("h_eT_ihcal"))
h_eT_ampt_ihcal.SetDirectory(0)
h_eT_ampt_ohcal = TH1F(f4.Get("h_eT_ohcal"))
h_eT_ampt_ohcal.SetDirectory(0)
f4.Close()
f5 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_zs_50ADC_data_noweight_0-90.root")
h_sim1_emcal = TH1F(f5.Get("h_event_emcal_energy"))
h_sim1_emcal.SetDirectory(0)
h_sim1_ihcal = TH1F(f5.Get("h_event_ihcal_energy"))
h_sim1_ihcal.SetDirectory(0)
h_sim1_ohcal = TH1F(f5.Get("h_event_ohcal_energy"))
h_sim1_ohcal.SetDirectory(0)
h_eT_sim1_emcal = TH1F(f5.Get("h_eT_emcal"))
h_eT_sim1_emcal.SetDirectory(0)
h_eT_sim1_ihcal = TH1F(f5.Get("h_eT_ihcal"))
h_eT_sim1_ihcal.SetDirectory(0)
h_eT_sim1_ohcal = TH1F(f5.Get("h_eT_ohcal"))
h_eT_sim1_ohcal.SetDirectory(0)
f5.Close()
f6 = ROOT.TFile.Open("dETdeta_analysis_23727_z=0_p011_nozs_data_noweight_0-90.root")
h_data1_emcal = TH1F(f6.Get("h_event_emcal_energy"))
h_data1_emcal.SetDirectory(0)
h_data1_ihcal = TH1F(f6.Get("h_event_ihcal_energy"))
h_data1_ihcal.SetDirectory(0)
h_data1_ohcal = TH1F(f6.Get("h_event_ohcal_energy"))
h_data1_ohcal.SetDirectory(0)
h_eT_data1_emcal = TH1F(f6.Get("h_eT_emcal"))
h_eT_data1_ihcal = TH1F(f6.Get("h_eT_ihcal"))
h_eT_data1_ohcal = TH1F(f6.Get("h_eT_ohcal"))
h_eT_data1_emcal.SetDirectory(0)
h_eT_data1_ihcal.SetDirectory(0)
h_eT_data1_ohcal.SetDirectory(0)
f6.Close()

# %%
h_data1_emcal.Rebin(2)
h_epos_emcal.Rebin(2)
h_data_emcal.Rebin(2)
h_sim_emcal.Rebin(2)
h_ampt_emcal.Rebin(2)
h_sim1_emcal.Rebin(2)
h_data1_emcal.Scale(1.0/h_data1_emcal.Integral())
h_epos_emcal.Scale(1.0/h_epos_emcal.Integral())
h_data_emcal.Scale(1.0/h_data_emcal.Integral())
h_sim_emcal.Scale(1.0/h_sim_emcal.Integral())
h_ampt_emcal.Scale(1.0/h_ampt_emcal.Integral())
h_sim1_emcal.Scale(1.0/h_sim1_emcal.Integral())

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.27,.22,.55,.5)
leg.AddEntry("","Run 23727-p011 MB","")
leg.AddEntry(h_data1_emcal,"NO ZS","lep")
leg.AddEntry(h_epos_emcal,"10 ADC ZS","lep")
leg.AddEntry(h_data_emcal,"20 ADC ZS","lep")
leg.AddEntry(h_sim_emcal,"30 ADC ZS","lep")
leg.AddEntry(h_ampt_emcal,"40 ADC ZS","lep")
leg.AddEntry(h_sim1_emcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_data1_emcal.SetStats(0)
h_data_emcal.SetStats(0)
h_sim_emcal.SetStats(0)
h_sim1_emcal.SetStats(0)
h_epos_emcal.SetStats(0)
h_ampt_emcal.SetStats(0)
h_data1_emcal.SetLineColor(1)
h_data1_emcal.SetMarkerColor(1)
h_data_emcal.SetLineColor(7)
h_sim_emcal.SetLineColor(6)
h_epos_emcal.SetLineColor(2)
h_ampt_emcal.SetLineColor(3)
h_sim1_emcal.SetLineColor(4)
h_data_emcal.SetMarkerColor(7)
h_sim_emcal.SetMarkerColor(6)
h_epos_emcal.SetMarkerColor(2)
h_ampt_emcal.SetMarkerColor(3)
h_sim1_emcal.SetMarkerColor(4)
h_data_emcal.GetXaxis().SetRangeUser(800,1500)
h_sim_emcal.GetXaxis().SetRangeUser(800,1500)
h_sim1_emcal.GetXaxis().SetRangeUser(800,1500)
h_epos_emcal.GetXaxis().SetRangeUser(800,1500)
h_ampt_emcal.GetXaxis().SetRangeUser(800,1500)
h_data_emcal.SetXTitle("#SigmaE_{T,EMCal} [GeV]")
h_data_emcal.Draw()
h_data1_emcal.Draw('same')
h_sim_emcal.Draw('same')
h_sim1_emcal.Draw('same')
h_epos_emcal.Draw('same')
h_ampt_emcal.Draw('same')
leg.Draw()
canvas.SetLogy(1)
canvas.Draw()
#canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/emcal_totalET_multi_zs_p011.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.57,.62,.85,.9)
leg.AddEntry("","Run 23727-p011 MB","")
leg.AddEntry(h_data1_ihcal,"NO ZS","lep")
leg.AddEntry(h_epos_ihcal,"10 ADC ZS","lep")
leg.AddEntry(h_data_ihcal,"20 ADC ZS","lep")
leg.AddEntry(h_sim_ihcal,"30 ADC ZS","lep")
leg.AddEntry(h_ampt_ihcal,"40 ADC ZS","lep")
leg.AddEntry(h_sim1_ihcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_data1_ihcal.SetStats(0)
h_data_ihcal.SetStats(0)
h_sim_ihcal.SetStats(0)
h_sim1_ihcal.SetStats(0)
h_epos_ihcal.SetStats(0)
h_ampt_ihcal.SetStats(0)
h_data1_ihcal.SetLineColor(1)
h_data1_ihcal.SetMarkerColor(1)
h_data_ihcal.SetLineColor(7)
h_sim_ihcal.SetLineColor(6)
h_epos_ihcal.SetLineColor(2)
h_ampt_ihcal.SetLineColor(3)
h_sim1_ihcal.SetLineColor(4)
h_data_ihcal.SetMarkerColor(7)
h_sim_ihcal.SetMarkerColor(6)
h_epos_ihcal.SetMarkerColor(2)
h_ampt_ihcal.SetMarkerColor(3)
h_sim1_ihcal.SetMarkerColor(4)
h_data_ihcal.GetXaxis().SetRangeUser(-10,20)
h_sim_ihcal.GetXaxis().SetRangeUser(-10,20)
h_sim1_ihcal.GetXaxis().SetRangeUser(-10,20)
h_epos_ihcal.GetXaxis().SetRangeUser(-10,20)
h_ampt_ihcal.GetXaxis().SetRangeUser(-10,20)
h_data_ihcal.SetXTitle("#SigmaE_{T,IHCal} [GeV]")
h_data_ihcal.Draw()
h_sim_ihcal.Draw('same')
h_sim1_ihcal.Draw('same')
h_epos_ihcal.Draw('same')
h_ampt_ihcal.Draw('same')
h_data1_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ihcal_totalET_multi_zs_p011.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/ihcal_totalET_multi_zs_p011.png has been created

# %%
# sim, 30 ADC
# data, 20 ZS
# epos, 10 ADC
# ampt, 40 ADC
# sim1, 50 ADC
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.57,.62,.85,.9)
leg.AddEntry("","Run 23727-p011 MB","")
leg.AddEntry(h_data1_ohcal,"NO ZS","lep")
leg.AddEntry(h_epos_ohcal,"10 ADC ZS","lep")
leg.AddEntry(h_data_ohcal,"20 ADC ZS","lep")
leg.AddEntry(h_sim_ohcal,"30 ADC ZS","lep")
leg.AddEntry(h_ampt_ohcal,"40 ADC ZS","lep")
leg.AddEntry(h_sim1_ohcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_data1_ohcal.SetStats(0)
h_data_ohcal.SetStats(0)
h_sim_ohcal.SetStats(0)
h_sim1_ohcal.SetStats(0)
h_epos_ohcal.SetStats(0)
h_ampt_ohcal.SetStats(0)
h_data1_ohcal.SetLineColor(1)
h_data1_ohcal.SetMarkerColor(1)
h_data_ohcal.SetLineColor(7)
h_sim_ohcal.SetLineColor(6)
h_epos_ohcal.SetLineColor(2)
h_ampt_ohcal.SetLineColor(3)
h_sim1_ohcal.SetLineColor(4)
h_data_ohcal.SetMarkerColor(7)
h_sim_ohcal.SetMarkerColor(6)
h_epos_ohcal.SetMarkerColor(2)
h_ampt_ohcal.SetMarkerColor(3)
h_sim1_ohcal.SetMarkerColor(4)
h_data_ohcal.GetXaxis().SetRangeUser(-10,30)
h_sim_ohcal.GetXaxis().SetRangeUser(-10,30)
h_sim1_ohcal.GetXaxis().SetRangeUser(-10,30)
h_epos_ohcal.GetXaxis().SetRangeUser(-10,30)
h_ampt_ohcal.GetXaxis().SetRangeUser(-10,30)
h_data_ohcal.SetXTitle("#SigmaE_{T,OHCal} [GeV]")
h_data_ohcal.Draw()
h_sim_ohcal.Draw('same')
h_sim1_ohcal.Draw('same')
h_epos_ohcal.Draw('same')
h_ampt_ohcal.Draw('same')
h_data1_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ohcal_totalET_multi_zs_p011.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/ohcal_totalET_multi_zs_p011.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.18,.6,.55)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(h_eT_data_emcal,"NO ZS","lep")
leg.AddEntry(h_eT_epos_emcal,"10 ADC ZS","lep")
leg.AddEntry(h_eT_ampt_emcal,"15 ADC ZS","lep")
leg.AddEntry(h_eT_sim1_emcal,"20 ADC ZS","lep")
leg.AddEntry(h_eT_data1_emcal,"25 ADC ZS","lep")
leg.AddEntry(h_eT_sim_emcal,"30 ADC ZS","lep")
leg.AddEntry(h_eT_data2_emcal,"40 ADC ZS","lep")
leg.AddEntry(h_eT_data3_emcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_emcal.SetStats(0)
h_eT_data1_emcal.SetStats(0)
h_eT_sim_emcal.SetStats(0)
h_eT_sim1_emcal.SetStats(0)
h_eT_epos_emcal.SetStats(0)
h_eT_ampt_emcal.SetStats(0)
h_eT_data2_emcal.SetStats(0)
h_eT_data3_emcal.SetStats(0)
h_eT_data1_emcal.SetYTitle("EMCal Reco dE_{T}/d#eta [GeV]")
h_eT_data1_emcal.SetXTitle("#eta")
h_eT_data_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data3_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_emcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_data1_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_data2_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_data3_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_sim_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_sim1_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_epos_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_ampt_emcal.GetYaxis().SetRangeUser(0,220)
h_eT_data_emcal.SetLineColor(1)
h_eT_data1_emcal.SetLineColor(7)
h_eT_data2_emcal.SetLineColor(8)
h_eT_data3_emcal.SetLineColor(11)
h_eT_sim_emcal.SetLineColor(6)
h_eT_epos_emcal.SetLineColor(2)
h_eT_ampt_emcal.SetLineColor(3)
h_eT_sim1_emcal.SetLineColor(4)
h_eT_data_emcal.SetMarkerColor(1)
h_eT_data1_emcal.SetMarkerColor(7)
h_eT_data2_emcal.SetMarkerColor(8)
h_eT_data3_emcal.SetMarkerColor(11)
h_eT_sim_emcal.SetMarkerColor(6)
h_eT_epos_emcal.SetMarkerColor(2)
h_eT_ampt_emcal.SetMarkerColor(3)
h_eT_sim1_emcal.SetMarkerColor(4)
h_eT_data1_emcal.Draw()
h_eT_epos_emcal.Draw('same')
h_eT_ampt_emcal.Draw('same')
h_eT_sim_emcal.Draw('same')
h_eT_sim1_emcal.Draw('same')
h_eT_data_emcal.Draw('same')
h_eT_data2_emcal.Draw('same')
h_eT_data3_emcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/emcal_reco_zs_crosscalib.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/emcal_reco_zs_crosscalib.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.25,.5,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(h_eT_data_ihcal,"NO ZS","lep")
leg.AddEntry(h_eT_epos_ihcal,"10 ADC ZS","lep")
leg.AddEntry(h_eT_ampt_ihcal,"15 ADC ZS","lep")
leg.AddEntry(h_eT_sim1_ihcal,"20 ADC ZS","lep")
leg.AddEntry(h_eT_data1_ihcal,"25 ADC ZS","lep")
leg.AddEntry(h_eT_sim_ihcal,"30 ADC ZS","lep")
leg.AddEntry(h_eT_data2_ihcal,"40 ADC ZS","lep")
leg.AddEntry(h_eT_data3_ihcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_ihcal.SetStats(0)
h_eT_data1_ihcal.SetStats(0)
h_eT_sim_ihcal.SetStats(0)
h_eT_sim1_ihcal.SetStats(0)
h_eT_epos_ihcal.SetStats(0)
h_eT_ampt_ihcal.SetStats(0)
h_eT_data2_ihcal.SetStats(0)
h_eT_data3_ihcal.SetStats(0)
h_eT_data1_ihcal.SetYTitle("IHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data1_ihcal.SetXTitle("#eta")
h_eT_data_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data3_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_data1_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_data2_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_data3_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_sim_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_sim1_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_epos_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_ampt_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_data_ihcal.SetLineColor(1)
h_eT_data1_ihcal.SetLineColor(7)
h_eT_data2_ihcal.SetLineColor(8)
h_eT_data3_ihcal.SetLineColor(11)
h_eT_sim_ihcal.SetLineColor(6)
h_eT_epos_ihcal.SetLineColor(2)
h_eT_ampt_ihcal.SetLineColor(3)
h_eT_sim1_ihcal.SetLineColor(4)
h_eT_data_ihcal.SetMarkerColor(1)
h_eT_data1_ihcal.SetMarkerColor(7)
h_eT_data2_ihcal.SetMarkerColor(8)
h_eT_data3_ihcal.SetMarkerColor(11)
h_eT_sim_ihcal.SetMarkerColor(6)
h_eT_epos_ihcal.SetMarkerColor(2)
h_eT_ampt_ihcal.SetMarkerColor(3)
h_eT_sim1_ihcal.SetMarkerColor(4)
h_eT_data1_ihcal.Draw()
h_eT_epos_ihcal.Draw('same')
h_eT_ampt_ihcal.Draw('same')
h_eT_sim_ihcal.Draw('same')
h_eT_sim1_ihcal.Draw('same')
h_eT_data_ihcal.Draw('same')
h_eT_data2_ihcal.Draw('same')
h_eT_data3_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/ihcal_reco_zs_crosscalib.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/ihcal_reco_zs_crosscalib.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.25,.5,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(h_eT_data_ohcal,"NO ZS","lep")
leg.AddEntry(h_eT_epos_ohcal,"10 ADC ZS","lep")
leg.AddEntry(h_eT_ampt_ohcal,"15 ADC ZS","lep")
leg.AddEntry(h_eT_sim1_ohcal,"20 ADC ZS","lep")
leg.AddEntry(h_eT_data1_ohcal,"25 ADC ZS","lep")
leg.AddEntry(h_eT_sim_ohcal,"30 ADC ZS","lep")
leg.AddEntry(h_eT_data2_ohcal,"40 ADC ZS","lep")
leg.AddEntry(h_eT_data3_ohcal,"50 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_ohcal.SetStats(0)
h_eT_data1_ohcal.SetStats(0)
h_eT_sim_ohcal.SetStats(0)
h_eT_sim1_ohcal.SetStats(0)
h_eT_epos_ohcal.SetStats(0)
h_eT_ampt_ohcal.SetStats(0)
h_eT_data2_ohcal.SetStats(0)
h_eT_data3_ohcal.SetStats(0)
h_eT_data1_ohcal.SetYTitle("OHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data1_ohcal.SetXTitle("#eta")
h_eT_data_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data3_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_data1_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_data2_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_data3_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_sim_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_sim1_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_epos_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_ampt_ohcal.GetYaxis().SetRangeUser(0,100)
h_eT_data_ohcal.SetLineColor(1)
h_eT_data1_ohcal.SetLineColor(7)
h_eT_data2_ohcal.SetLineColor(8)
h_eT_data3_ohcal.SetLineColor(11)
h_eT_sim_ohcal.SetLineColor(6)
h_eT_epos_ohcal.SetLineColor(2)
h_eT_ampt_ohcal.SetLineColor(3)
h_eT_sim1_ohcal.SetLineColor(4)
h_eT_data_ohcal.SetMarkerColor(1)
h_eT_data1_ohcal.SetMarkerColor(7)
h_eT_data2_ohcal.SetMarkerColor(8)
h_eT_data3_ohcal.SetMarkerColor(11)
h_eT_sim_ohcal.SetMarkerColor(6)
h_eT_epos_ohcal.SetMarkerColor(2)
h_eT_ampt_ohcal.SetMarkerColor(3)
h_eT_sim1_ohcal.SetMarkerColor(4)
h_eT_data1_ohcal.Draw()
h_eT_epos_ohcal.Draw('same')
h_eT_ampt_ohcal.Draw('same')
h_eT_sim_ohcal.Draw('same')
h_eT_sim1_ohcal.Draw('same')
h_eT_data_ohcal.Draw('same')
h_eT_data2_ohcal.Draw('same')
h_eT_data3_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/ohcal_reco_zs_crosscalib.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/ohcal_reco_zs_crosscalib.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

timing = TH1F(h_eT_sim1_emcal.Clone("timing"))
timing.Divide(h_eT_data_emcal)
energy = TH1F(h_eT_sim_emcal.Clone("energy"))
energy.Divide(h_eT_data_emcal)
both = TH1F(h_eT_data1_emcal.Clone("both"))
both.Divide(h_eT_data_emcal)
both1 = TH1F(h_eT_epos_emcal.Clone("both1"))
both1.Divide(h_eT_data_emcal)
both2 = TH1F(h_eT_ampt_emcal.Clone("both2"))
both2.Divide(h_eT_data_emcal)
both3 = TH1F(h_eT_data2_emcal.Clone("both3"))
both3.Divide(h_eT_data_emcal)
both4 = TH1F(h_eT_data3_emcal.Clone("both4"))
both4.Divide(h_eT_data_emcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.55,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both1,"10 ADC ZS / NO ZS","lep")
leg.AddEntry(both2,"15 ADC ZS / NO ZS","lep")
leg.AddEntry(timing,"20 ADC ZS / NO ZS","lep")
leg.AddEntry(both,"25 ADC ZS / NO ZS","lep")
leg.AddEntry(energy,"30 ADC ZS / NO ZS","lep")
leg.AddEntry(both3,"40 ADC ZS / NO ZS","lep")
leg.AddEntry(both4,"50 ADC ZS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(6)
energy.SetMarkerColor(6)
both.SetLineColor(7)
both.SetMarkerColor(7)
both1.SetLineColor(2)
both1.SetMarkerColor(2)
both2.SetLineColor(3)
both2.SetMarkerColor(3)
timing.SetLineColor(4)
timing.SetMarkerColor(4)
both3.SetLineColor(8)
both3.SetMarkerColor(8)
both4.SetLineColor(11)
both4.SetMarkerColor(11)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
both1.SetStats(0)
both2.SetStats(0)
both3.SetStats(0)
both4.SetStats(0)
energy.GetYaxis().SetRangeUser(0.7,1.3)
both.GetYaxis().SetRangeUser(0.7,1.3)
both1.GetYaxis().SetRangeUser(0.7,1.3)
both2.GetYaxis().SetRangeUser(0.7,1.3)
both3.GetYaxis().SetRangeUser(0.7,1.3)
both4.GetYaxis().SetRangeUser(0.7,1.3)
timing.GetYaxis().SetRangeUser(0.7,1.3)
energy.SetYTitle('Reco EMCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
both1.Draw('same')
both2.Draw('same')
timing.Draw('same')
both3.Draw('same')
both4.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/emcal_reco_zs_crosscalib_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/emcal_reco_zs_crosscalib_ratio.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

timing = TH1F(h_eT_sim1_ihcal.Clone("timing"))
timing.Divide(h_eT_data_ihcal)
energy = TH1F(h_eT_sim_ihcal.Clone("energy"))
energy.Divide(h_eT_data_ihcal)
both = TH1F(h_eT_data1_ihcal.Clone("both"))
both.Divide(h_eT_data_ihcal)
both1 = TH1F(h_eT_epos_ihcal.Clone("both1"))
both1.Divide(h_eT_data_ihcal)
both2 = TH1F(h_eT_ampt_ihcal.Clone("both2"))
both2.Divide(h_eT_data_ihcal)
both3 = TH1F(h_eT_data2_ihcal.Clone("both3"))
both3.Divide(h_eT_data_ihcal)
both4 = TH1F(h_eT_data3_ihcal.Clone("both4"))
both4.Divide(h_eT_data_ihcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.55,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both1,"10 ADC ZS / NO ZS","lep")
leg.AddEntry(both2,"15 ADC ZS / NO ZS","lep")
leg.AddEntry(timing,"20 ADC ZS / NO ZS","lep")
leg.AddEntry(both,"25 ADC ZS / NO ZS","lep")
leg.AddEntry(energy,"30 ADC ZS / NO ZS","lep")
leg.AddEntry(both3,"40 ADC ZS / NO ZS","lep")
leg.AddEntry(both4,"50 ADC ZS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(6)
energy.SetMarkerColor(6)
both.SetLineColor(7)
both.SetMarkerColor(7)
both1.SetLineColor(2)
both1.SetMarkerColor(2)
both2.SetLineColor(3)
both2.SetMarkerColor(3)
timing.SetLineColor(4)
timing.SetMarkerColor(4)
both3.SetLineColor(8)
both3.SetMarkerColor(8)
both4.SetLineColor(11)
both4.SetMarkerColor(11)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
both1.SetStats(0)
both2.SetStats(0)
both3.SetStats(0)
both4.SetStats(0)
energy.GetYaxis().SetRangeUser(0.95,1.05)
both.GetYaxis().SetRangeUser(0.95,1.05)
both1.GetYaxis().SetRangeUser(0.95,1.05)
both2.GetYaxis().SetRangeUser(0.95,1.05)
both3.GetYaxis().SetRangeUser(0.95,1.05)
both4.GetYaxis().SetRangeUser(0.95,1.05)
timing.GetYaxis().SetRangeUser(0.95,1.05)
energy.SetYTitle('Reco IHCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
both1.Draw('same')
both2.Draw('same')
timing.Draw('same')
both3.Draw('same')
both4.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/ihcal_reco_zs_crosscalib_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/ihcal_reco_zs_crosscalib_ratio.png has been created

# %%
# sim, 30 ADC
# data, NO ZS
# epos, 10 ADC
# ampt, 15 ADC
# sim1, 20 ADC
# data1, 25 ADC

timing = TH1F(h_eT_sim1_ohcal.Clone("timing"))
timing.Divide(h_eT_data_ohcal)
energy = TH1F(h_eT_sim_ohcal.Clone("energy"))
energy.Divide(h_eT_data_ohcal)
both = TH1F(h_eT_data1_ohcal.Clone("both"))
both.Divide(h_eT_data_ohcal)
both1 = TH1F(h_eT_epos_ohcal.Clone("both1"))
both1.Divide(h_eT_data_ohcal)
both2 = TH1F(h_eT_ampt_ohcal.Clone("both2"))
both2.Divide(h_eT_data_ohcal)
both3 = TH1F(h_eT_data2_ohcal.Clone("both3"))
both3.Divide(h_eT_data_ohcal)
both4 = TH1F(h_eT_data3_ohcal.Clone("both4"))
both4.Divide(h_eT_data_ohcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.2,.58,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both1,"10 ADC ZS / NO ZS","lep")
leg.AddEntry(both2,"15 ADC ZS / NO ZS","lep")
leg.AddEntry(timing,"20 ADC ZS / NO ZS","lep")
leg.AddEntry(both,"25 ADC ZS / NO ZS","lep")
leg.AddEntry(energy,"30 ADC ZS / NO ZS","lep")
leg.AddEntry(both3,"40 ADC ZS / NO ZS","lep")
leg.AddEntry(both4,"50 ADC ZS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(6)
energy.SetMarkerColor(6)
both.SetLineColor(7)
both.SetMarkerColor(7)
both1.SetLineColor(2)
both1.SetMarkerColor(2)
both2.SetLineColor(3)
both2.SetMarkerColor(3)
timing.SetLineColor(4)
timing.SetMarkerColor(4)
both3.SetLineColor(8)
both3.SetMarkerColor(8)
both4.SetLineColor(11)
both4.SetMarkerColor(11)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
both1.SetStats(0)
both2.SetStats(0)
both3.SetStats(0)
both4.SetStats(0)
energy.GetYaxis().SetRangeUser(0.9,1.1)
both.GetYaxis().SetRangeUser(0.9,1.1)
both1.GetYaxis().SetRangeUser(0.9,1.1)
both2.GetYaxis().SetRangeUser(0.9,1.1)
both3.GetYaxis().SetRangeUser(0.9,1.1)
both4.GetYaxis().SetRangeUser(0.9,1.1)
timing.GetYaxis().SetRangeUser(0.9,1.1)
energy.SetYTitle('Reco OHCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
both1.Draw('same')
both2.Draw('same')
timing.Draw('same')
both3.Draw('same')
both4.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_15/ohcal_reco_zs_crosscalib_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_15/ohcal_reco_zs_crosscalib_ratio.png has been created

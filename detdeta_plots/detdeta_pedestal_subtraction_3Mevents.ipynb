# %%
import ROOT
from ROOT import TCanvas, TFile, TProfile, TNtuple, TH1I, TH1F, TH2F, TH3F, TColor, TEfficiency
from ROOT import gROOT, gBenchmark, gRandom, gSystem
import numpy as np
import pdb
from array import array
# Out:
# Welcome to JupyROOT 6.26/06

# %%
# %cd /sphenix/u/egm2153/spring_2023
gROOT.LoadMacro("sPhenixStyle.C");
gROOT.ProcessLine("SetsPhenixStyle()")
# Out:
# /direct/sphenix+u/egm2153/spring_2023
# 0
# sPhenixStyle: Applying nominal settings.
# sPhenixStyle: ROOT6 mode

# %%
# %cd /sphenix/user/egm2153/calib_study/detdeta/analysis/pedestal_subtraction
# Out:
# /gpfs/mnt/gpfs02/sphenix/user/egm2153/calib_study/detdeta/analysis/pedestal_subtraction

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

f1 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_zs_30ADC_reweighted_bins.root")
h_eT_data_emcal = TH1F(f1.Get("h_eT_emcal"))
h_eT_data_ihcal = TH1F(f1.Get("h_eT_ihcal"))
h_eT_data_ohcal = TH1F(f1.Get("h_eT_ohcal"))
h_eT_data_emcal.SetDirectory(0)
h_eT_data_ihcal.SetDirectory(0)
h_eT_data_ohcal.SetDirectory(0)
h_em_data_zs_rate = TH1I(f1.Get("h_em_zs_rate"))
h_ih_data_zs_rate = TH1I(f1.Get("h_ih_zs_rate"))
h_oh_data_zs_rate = TH1I(f1.Get("h_oh_zs_rate"))
h_em_data_zs_rate.SetDirectory(0)
h_ih_data_zs_rate.SetDirectory(0)
h_oh_data_zs_rate.SetDirectory(0)
h_data_emcal = TH1F(f1.Get("h_event_emcal_energy"))
h_data_emcal.SetDirectory(0)
h_data_ihcal = TH1F(f1.Get("h_event_ihcal_energy"))
h_data_ihcal.SetDirectory(0)
h_data_ohcal = TH1F(f1.Get("h_event_ohcal_energy"))
h_data_ohcal.SetDirectory(0)
f1.Close()
f2 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_nozs_no_cross_calib_reweighted_bins.root")
h_eT_data1_emcal = TH1F(f2.Get("h_eT_emcal"))
h_eT_data1_ihcal = TH1F(f2.Get("h_eT_ihcal"))
h_eT_data1_ohcal = TH1F(f2.Get("h_eT_ohcal"))
h_eT_data1_emcal.SetDirectory(0)
h_eT_data1_ihcal.SetDirectory(0)
h_eT_data1_ohcal.SetDirectory(0)
h_data1_emcal = TH1F(f2.Get("h_event_emcal_energy"))
h_data1_emcal.SetDirectory(0)
h_data1_ihcal = TH1F(f2.Get("h_event_ihcal_energy"))
h_data1_ihcal.SetDirectory(0)
h_data1_ohcal = TH1F(f2.Get("h_event_ohcal_energy"))
h_data1_ohcal.SetDirectory(0)
f2.Close()
f3 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_zs_20ADC_reweighted_bins.root")
h_eT_epos_emcal = TH1F(f3.Get("h_eT_emcal"))
h_eT_epos_ihcal = TH1F(f3.Get("h_eT_ihcal"))
h_eT_epos_ohcal = TH1F(f3.Get("h_eT_ohcal"))
h_eT_epos_emcal.SetDirectory(0)
h_eT_epos_ihcal.SetDirectory(0)
h_eT_epos_ohcal.SetDirectory(0)
h_em_epos_zs_rate = TH1I(f3.Get("h_em_zs_rate"))
h_ih_epos_zs_rate = TH1I(f3.Get("h_ih_zs_rate"))
h_oh_epos_zs_rate = TH1I(f3.Get("h_oh_zs_rate"))
h_em_epos_zs_rate.SetDirectory(0)
h_ih_epos_zs_rate.SetDirectory(0)
h_oh_epos_zs_rate.SetDirectory(0)
h_epos_emcal = TH1F(f3.Get("h_event_emcal_energy"))
h_epos_emcal.SetDirectory(0)
h_epos_ihcal = TH1F(f3.Get("h_event_ihcal_energy"))
h_epos_ihcal.SetDirectory(0)
h_epos_ohcal = TH1F(f3.Get("h_event_ohcal_energy"))
h_epos_ohcal.SetDirectory(0)
f3.Close()
f4 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_zs_10ADC_reweighted_bins.root")
h_eT_ampt_emcal = TH1F(f4.Get("h_eT_emcal"))
h_eT_ampt_ihcal = TH1F(f4.Get("h_eT_ihcal"))
h_eT_ampt_ohcal = TH1F(f4.Get("h_eT_ohcal"))
h_eT_ampt_emcal.SetDirectory(0)
h_eT_ampt_ihcal.SetDirectory(0)
h_eT_ampt_ohcal.SetDirectory(0)
h_em_ampt_zs_rate = TH1I(f4.Get("h_em_zs_rate"))
h_ih_ampt_zs_rate = TH1I(f4.Get("h_ih_zs_rate"))
h_oh_ampt_zs_rate = TH1I(f4.Get("h_oh_zs_rate"))
h_em_ampt_zs_rate.SetDirectory(0)
h_ih_ampt_zs_rate.SetDirectory(0)
h_oh_ampt_zs_rate.SetDirectory(0)
h_ampt_emcal = TH1F(f4.Get("h_event_emcal_energy"))
h_ampt_emcal.SetDirectory(0)
h_ampt_ihcal = TH1F(f4.Get("h_event_ihcal_energy"))
h_ampt_ihcal.SetDirectory(0)
h_ampt_ohcal = TH1F(f4.Get("h_event_ohcal_energy"))
h_ampt_ohcal.SetDirectory(0)
f4.Close()
f5 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_zs_30ADC_no_cross_calib_reweighted_bins.root")
h_eT_sim1_emcal = TH1F(f5.Get("h_eT_emcal"))
h_eT_sim1_ihcal = TH1F(f5.Get("h_eT_ihcal"))
h_eT_sim1_ohcal = TH1F(f5.Get("h_eT_ohcal"))
h_eT_sim1_emcal.SetDirectory(0)
h_eT_sim1_ihcal.SetDirectory(0)
h_eT_sim1_ohcal.SetDirectory(0)
h_em_sim1_zs_rate = TH1I(f5.Get("h_em_zs_rate"))
h_ih_sim1_zs_rate = TH1I(f5.Get("h_ih_zs_rate"))
h_oh_sim1_zs_rate = TH1I(f5.Get("h_oh_zs_rate"))
h_em_sim1_zs_rate.SetDirectory(0)
h_ih_sim1_zs_rate.SetDirectory(0)
h_oh_sim1_zs_rate.SetDirectory(0)
h_sim1_emcal = TH1F(f5.Get("h_event_emcal_energy"))
h_sim1_emcal.SetDirectory(0)
h_sim1_ihcal = TH1F(f5.Get("h_event_ihcal_energy"))
h_sim1_ihcal.SetDirectory(0)
h_sim1_ohcal = TH1F(f5.Get("h_event_ohcal_energy"))
h_sim1_ohcal.SetDirectory(0)
f5.Close()
f6 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_zs_20ADC_no_cross_calib_reweighted_bins.root")
h_eT_sim_emcal = TH1F(f6.Get("h_eT_emcal"))
h_eT_sim_ihcal = TH1F(f6.Get("h_eT_ihcal"))
h_eT_sim_ohcal = TH1F(f6.Get("h_eT_ohcal"))
h_eT_sim_emcal.SetDirectory(0)
h_eT_sim_ihcal.SetDirectory(0)
h_eT_sim_ohcal.SetDirectory(0)
h_em_sim_zs_rate = TH1I(f6.Get("h_em_zs_rate"))
h_ih_sim_zs_rate = TH1I(f6.Get("h_ih_zs_rate"))
h_oh_sim_zs_rate = TH1I(f6.Get("h_oh_zs_rate"))
h_em_sim_zs_rate.SetDirectory(0)
h_ih_sim_zs_rate.SetDirectory(0)
h_oh_sim_zs_rate.SetDirectory(0)
h_sim_emcal = TH1F(f6.Get("h_event_emcal_energy"))
h_sim_emcal.SetDirectory(0)
h_sim_ihcal = TH1F(f6.Get("h_event_ihcal_energy"))
h_sim_ihcal.SetDirectory(0)
h_sim_ohcal = TH1F(f6.Get("h_event_ohcal_energy"))
h_sim_ohcal.SetDirectory(0)
f6.Close()
f7 = ROOT.TFile.Open("dETdeta_analysis_pedestal_subtraction_31521_zs_10ADC_no_cross_calib_reweighted_bins.root")
h_eT_data2_emcal = TH1F(f7.Get("h_eT_emcal"))
h_eT_data2_ihcal = TH1F(f7.Get("h_eT_ihcal"))
h_eT_data2_ohcal = TH1F(f7.Get("h_eT_ohcal"))
h_eT_data2_emcal.SetDirectory(0)
h_eT_data2_ihcal.SetDirectory(0)
h_eT_data2_ohcal.SetDirectory(0)
h_em_data2_zs_rate = TH1I(f7.Get("h_em_zs_rate"))
h_ih_data2_zs_rate = TH1I(f7.Get("h_ih_zs_rate"))
h_oh_data2_zs_rate = TH1I(f7.Get("h_oh_zs_rate"))
h_em_data2_zs_rate.SetDirectory(0)
h_ih_data2_zs_rate.SetDirectory(0)
h_oh_data2_zs_rate.SetDirectory(0)
h_data2_emcal = TH1F(f7.Get("h_event_emcal_energy"))
h_data2_emcal.SetDirectory(0)
h_data2_ihcal = TH1F(f7.Get("h_event_ihcal_energy"))
h_data2_ihcal.SetDirectory(0)
h_data2_ohcal = TH1F(f7.Get("h_event_ohcal_energy"))
h_data2_ohcal.SetDirectory(0)
f7.Close()

# %%
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.2,.2,.5,.39)
leg.AddEntry("","#it{#bf{sPHENIX}} Internal","")
leg.AddEntry("","Run 31521 3M events","")
leg.AddEntry(h_eT_data_ihcal,"30 ADC ZS + template fit","lep")
leg.AddEntry(h_eT_data1_ihcal,"Template fit","lep")
leg.SetBorderSize(0)
h_eT_data_ihcal.SetStats(0)
h_eT_data1_ihcal.SetStats(0)
h_eT_data_ihcal.SetYTitle("IHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ihcal.SetXTitle("#eta")
h_eT_data_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ihcal.GetYaxis().SetRangeUser(-0.3,0.3)
h_eT_data1_ihcal.GetYaxis().SetRangeUser(-0.3,0.3)
h_eT_data_ihcal.SetLineColor(1)
h_eT_data1_ihcal.SetLineColor(2)
h_eT_data_ihcal.SetMarkerColor(1)
h_eT_data1_ihcal.SetMarkerColor(2)
h_eT_data_ihcal.Draw()
h_eT_data1_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/detdeta_plots/ihcal_reco_pedestal_data_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/detdeta_plots/ihcal_reco_pedestal_data_3M.png has been created

# %%
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.2,.78,.5,.89)
leg.AddEntry("","Run 30146 226k events","")
leg.AddEntry(h_eT_data_ihcal,"30 ADC ZS","lep")
#leg.AddEntry(h_eT_data1_ihcal,"NO ZS","lep")
leg.SetBorderSize(0)
h_eT_data_ihcal.SetStats(0)
#h_eT_data1_ihcal.SetStats(0)
h_eT_data_ihcal.SetYTitle("IHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ihcal.SetXTitle("#eta")
h_eT_data_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
#h_eT_data1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ihcal.GetYaxis().SetRangeUser(-0.0005,0.0005)
#h_eT_data1_ihcal.GetYaxis().SetRangeUser(0,30)
h_eT_data_ihcal.SetLineColor(1)
#h_eT_data1_ihcal.SetLineColor(2)
h_eT_data_ihcal.SetMarkerColor(1)
#h_eT_data1_ihcal.SetMarkerColor(2)
h_eT_data_ihcal.Draw()
#h_eT_data1_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
#canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ihcal_reco_pedestal_data_zsonly.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.2,.2,.5,.39)
leg.AddEntry("","#it{#bf{sPHENIX}} Internal","")
leg.AddEntry("","Run 31521 3M events","")
leg.AddEntry(h_eT_data_ohcal,"30 ADC ZS + template fit","lep")
leg.AddEntry(h_eT_data1_ohcal,"Template fit","lep")
leg.SetBorderSize(0)
h_eT_data_ohcal.SetStats(0)
h_eT_data1_ohcal.SetStats(0)
h_eT_data_ohcal.SetYTitle("OHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ohcal.SetXTitle("#eta")
h_eT_data_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ohcal.GetYaxis().SetRangeUser(-1.5,1.5)
h_eT_data1_ohcal.GetYaxis().SetRangeUser(-1.5,1.5)
h_eT_data_ohcal.SetLineColor(1)
h_eT_data1_ohcal.SetLineColor(2)
h_eT_data_ohcal.SetMarkerColor(1)
h_eT_data1_ohcal.SetMarkerColor(2)
h_eT_data_ohcal.Draw()
h_eT_data1_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/detdeta_plots/ohcal_reco_pedestal_data_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/detdeta_plots/ohcal_reco_pedestal_data_3M.png has been created

# %%
canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.2,.78,.5,.89)
leg.AddEntry("","Run 30146 226k events","")
leg.AddEntry(h_eT_data_ohcal,"30 ADC ZS","lep")
#leg.AddEntry(h_eT_data1_ohcal,"25 ADC ZS","lep")
leg.SetBorderSize(0)
h_eT_data_ohcal.SetStats(0)
#h_eT_data1_ohcal.SetStats(0)
h_eT_data_ohcal.SetYTitle("OHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ohcal.SetXTitle("#eta")
h_eT_data_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
#h_eT_data1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ohcal.GetYaxis().SetRangeUser(-0.01,0.01)
#h_eT_data1_ohcal.GetYaxis().SetRangeUser(0,30)
h_eT_data_ohcal.SetLineColor(1)
#h_eT_data1_ohcal.SetLineColor(2)
h_eT_data_ohcal.SetMarkerColor(1)
#h_eT_data1_ohcal.SetMarkerColor(2)
h_eT_data_ohcal.Draw()
#h_eT_data1_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
#canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ohcal_reco_pedestal_data_zsonly.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.25,.59,.85,.91)
leg.AddEntry("","#it{#bf{sPHENIX}} Internal","")
leg.AddEntry("","Run 31521 3M events","")
leg.AddEntry(h_eT_ampt_ihcal,"10 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_epos_ihcal,"20 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_data_ihcal,"30 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_data2_ihcal,"10 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim_ihcal,"20 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim1_ihcal,"30 ADC ZS NO CROSS CALIB","lep")
leg.SetBorderSize(0)
h_eT_data_ihcal.SetStats(0)
h_eT_data1_ihcal.SetStats(0)
h_eT_sim_ihcal.SetStats(0)
h_eT_sim1_ihcal.SetStats(0)
h_eT_epos_ihcal.SetStats(0)
h_eT_ampt_ihcal.SetStats(0)
h_eT_data2_ihcal.SetStats(0)
h_eT_data_ihcal.SetYTitle("IHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ihcal.SetXTitle("#eta")
h_eT_data_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_data1_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_data2_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_sim_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_sim1_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_epos_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_ampt_ihcal.GetYaxis().SetRangeUser(-0.012,0.012)
h_eT_data_ihcal.SetLineColor(1)
h_eT_data1_ihcal.SetLineColor(7)
h_eT_data2_ihcal.SetLineColor(7)
h_eT_sim_ihcal.SetLineColor(6)
h_eT_epos_ihcal.SetLineColor(2)
h_eT_ampt_ihcal.SetLineColor(3)
h_eT_sim1_ihcal.SetLineColor(4)
h_eT_data_ihcal.SetMarkerColor(1)
h_eT_data1_ihcal.SetMarkerColor(7)
h_eT_data2_ihcal.SetMarkerColor(7)
h_eT_sim_ihcal.SetMarkerColor(6)
h_eT_epos_ihcal.SetMarkerColor(2)
h_eT_ampt_ihcal.SetMarkerColor(3)
h_eT_sim1_ihcal.SetMarkerColor(4)
#h_eT_data1_ihcal.Draw()
h_eT_data_ihcal.Draw()
h_eT_ampt_ihcal.Draw('same')
h_eT_sim_ihcal.Draw('same')
h_eT_sim1_ihcal.Draw('same')
h_eT_epos_ihcal.Draw('same')
h_eT_data2_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/detdeta_plots/ihcal_reco_pedestal_data_multi_zs_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/detdeta_plots/ihcal_reco_pedestal_data_multi_zs_3M.png has been created

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.25,.19,.85,.44)
leg.AddEntry("","#it{#bf{sPHENIX}} Internal","")
leg.AddEntry("","Run 31521 3M events","")
#leg.AddEntry(h_eT_data1_ihcal,"NO ZS","lep")
#leg.AddEntry(h_eT_ampt_ihcal,"10 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_epos_ihcal,"20 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_data_ihcal,"30 ADC ZS CROSS CALIB","lep")
#leg.AddEntry(h_eT_data2_ihcal,"10 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim_ihcal,"20 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim1_ihcal,"30 ADC ZS NO CROSS CALIB","lep")
leg.SetBorderSize(0)
h_eT_data_ihcal.SetStats(0)
h_eT_data1_ihcal.SetStats(0)
h_eT_sim_ihcal.SetStats(0)
h_eT_sim1_ihcal.SetStats(0)
h_eT_epos_ihcal.SetStats(0)
h_eT_ampt_ihcal.SetStats(0)
h_eT_data2_ihcal.SetStats(0)
h_eT_data_ihcal.SetYTitle("IHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ihcal.SetXTitle("#eta")
h_eT_data_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ihcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_data1_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_data2_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_sim_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_sim1_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_epos_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_ampt_ihcal.GetYaxis().SetRangeUser(-0.0006,0.0006)
h_eT_data_ihcal.SetLineColor(1)
h_eT_data1_ihcal.SetLineColor(7)
h_eT_data2_ihcal.SetLineColor(7)
h_eT_sim_ihcal.SetLineColor(6)
h_eT_epos_ihcal.SetLineColor(2)
h_eT_ampt_ihcal.SetLineColor(3)
h_eT_sim1_ihcal.SetLineColor(4)
h_eT_data_ihcal.SetMarkerColor(1)
h_eT_data1_ihcal.SetMarkerColor(7)
h_eT_data2_ihcal.SetMarkerColor(7)
h_eT_sim_ihcal.SetMarkerColor(6)
h_eT_epos_ihcal.SetMarkerColor(2)
h_eT_ampt_ihcal.SetMarkerColor(3)
h_eT_sim1_ihcal.SetMarkerColor(4)
#h_eT_data1_ihcal.Draw()
h_eT_data_ihcal.Draw()
#h_eT_ampt_ihcal.Draw('same')
h_eT_sim_ihcal.Draw('same')
h_eT_sim1_ihcal.Draw('same')
h_eT_epos_ihcal.Draw('same')
#h_eT_data2_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/detdeta_plots/ihcal_reco_pedestal_data_20_30_zs_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/detdeta_plots/ihcal_reco_pedestal_data_20_30_zs_3M.png has been created

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.25,.59,.85,.91)
leg.AddEntry("","#it{#bf{sPHENIX}} Internal","")
leg.AddEntry("","Run 31521 3M events","")
#leg.AddEntry(h_eT_data1_ohcal,"NO ZS","lep")
leg.AddEntry(h_eT_ampt_ohcal,"10 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_epos_ohcal,"20 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_data_ohcal,"30 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_data2_ohcal,"10 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim_ohcal,"20 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim1_ohcal,"30 ADC ZS NO CROSS CALIB","lep")
leg.SetBorderSize(0)
h_eT_data_ohcal.SetStats(0)
h_eT_data1_ohcal.SetStats(0)
h_eT_sim_ohcal.SetStats(0)
h_eT_sim1_ohcal.SetStats(0)
h_eT_epos_ohcal.SetStats(0)
h_eT_ampt_ohcal.SetStats(0)
h_eT_data2_ohcal.SetStats(0)
h_eT_data_ohcal.SetYTitle("OHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ohcal.SetXTitle("#eta")
h_eT_data_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_data1_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_data2_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_sim_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_sim1_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_epos_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_ampt_ohcal.GetYaxis().SetRangeUser(-0.15,0.15)
h_eT_data_ohcal.SetLineColor(1)
h_eT_data1_ohcal.SetLineColor(7)
h_eT_data2_ohcal.SetLineColor(7)
h_eT_sim_ohcal.SetLineColor(6)
h_eT_epos_ohcal.SetLineColor(2)
h_eT_ampt_ohcal.SetLineColor(3)
h_eT_sim1_ohcal.SetLineColor(4)
h_eT_data_ohcal.SetMarkerColor(1)
h_eT_data1_ohcal.SetMarkerColor(7)
h_eT_data2_ohcal.SetMarkerColor(7)
h_eT_sim_ohcal.SetMarkerColor(6)
h_eT_epos_ohcal.SetMarkerColor(2)
h_eT_ampt_ohcal.SetMarkerColor(3)
h_eT_sim1_ohcal.SetMarkerColor(4)
#h_eT_data1_ohcal.Draw()
h_eT_data_ohcal.Draw()
h_eT_ampt_ohcal.Draw('same')
h_eT_sim_ohcal.Draw('same')
h_eT_sim1_ohcal.Draw('same')
h_eT_epos_ohcal.Draw('same')
h_eT_data2_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/detdeta_plots/ohcal_reco_pedestal_data_multi_zs_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/detdeta_plots/ohcal_reco_pedestal_data_multi_zs_3M.png has been created

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.25,.19,.85,.46)
leg.AddEntry("","#it{#bf{sPHENIX}} Internal","")
leg.AddEntry("","Run 31521 3M events","")
#leg.AddEntry(h_eT_data1_ohcal,"NO ZS","lep")
#leg.AddEntry(h_eT_ampt_ohcal,"10 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_epos_ohcal,"20 ADC ZS CROSS CALIB","lep")
leg.AddEntry(h_eT_data_ohcal,"30 ADC ZS CROSS CALIB","lep")
#leg.AddEntry(h_eT_data2_ohcal,"10 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim_ohcal,"20 ADC ZS NO CROSS CALIB","lep")
leg.AddEntry(h_eT_sim1_ohcal,"30 ADC ZS NO CROSS CALIB","lep")
leg.SetBorderSize(0)
h_eT_data_ohcal.SetStats(0)
h_eT_data1_ohcal.SetStats(0)
h_eT_sim_ohcal.SetStats(0)
h_eT_sim1_ohcal.SetStats(0)
h_eT_epos_ohcal.SetStats(0)
h_eT_ampt_ohcal.SetStats(0)
h_eT_data2_ohcal.SetStats(0)
h_eT_data_ohcal.SetYTitle("OHCal Reco dE_{T}/d#eta [GeV]")
h_eT_data_ohcal.SetXTitle("#eta")
h_eT_data_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data2_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_sim1_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_epos_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_ampt_ohcal.GetXaxis().SetRangeUser(-1.05,1.1)
h_eT_data_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_data1_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_data2_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_sim_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_sim1_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_epos_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_ampt_ohcal.GetYaxis().SetRangeUser(-0.005,0.005)
h_eT_data_ohcal.SetLineColor(1)
h_eT_data1_ohcal.SetLineColor(7)
h_eT_data2_ohcal.SetLineColor(7)
h_eT_sim_ohcal.SetLineColor(6)
h_eT_epos_ohcal.SetLineColor(2)
h_eT_ampt_ohcal.SetLineColor(3)
h_eT_sim1_ohcal.SetLineColor(4)
h_eT_data_ohcal.SetMarkerColor(1)
h_eT_data1_ohcal.SetMarkerColor(7)
h_eT_data2_ohcal.SetMarkerColor(7)
h_eT_sim_ohcal.SetMarkerColor(6)
h_eT_epos_ohcal.SetMarkerColor(2)
h_eT_ampt_ohcal.SetMarkerColor(3)
h_eT_sim1_ohcal.SetMarkerColor(4)
#h_eT_data1_ohcal.Draw()
h_eT_data_ohcal.Draw()
#h_eT_ampt_ohcal.Draw('same')
h_eT_sim_ohcal.Draw('same')
#h_eT_sim1_ohcal.Draw('same')
h_eT_epos_ohcal.Draw('same')
#h_eT_data2_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/detdeta_plots/ohcal_reco_pedestal_data_20_30_zs_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/detdeta_plots/ohcal_reco_pedestal_data_20_30_zs_3M.png has been created

# %%
def divide_histograms(h1, h2):
    h3 = TH1F(h1.Clone("h3"))
    h3.Divide(h2)

    for i in range(1, h3.GetNbinsX() + 1):
        val1 = h1.GetBinContent(i)
        err1 = h1.GetBinError(i)
        val2 = h2.GetBinContent(i)
        err2 = h2.GetBinError(i)

        # Calculate error for h3 using error propagation formula
        val3 = h3.GetBinContent(i)
        err3 = 0.0
        if val2 != 0:
            err3 = abs(val3) * ((err1 / val1)**2 + (err2 / val2)**2)**0.5
        h3.SetBinError(i, err3)

    return h3

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

timing = divide_histograms(h_eT_data_ihcal, h_eT_sim1_ihcal)
energy = divide_histograms(h_eT_epos_ihcal, h_eT_sim_ihcal) 
both = divide_histograms(h_eT_ampt_ihcal, h_eT_data2_ihcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.55,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both,"30 ADC ZS CROSS / NO ZS","lep")
leg.AddEntry(energy,"20 ADC ZS NO CROSS / NO ZS","lep")
leg.AddEntry(timing,"30 ADC ZS NO CROSS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(3)
energy.SetMarkerColor(3)
both.SetLineColor(1)
both.SetMarkerColor(1)
timing.SetLineColor(2)
timing.SetMarkerColor(2)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
energy.GetYaxis().SetRangeUser(-2,4)
both.GetYaxis().SetRangeUser(-2,4)
timing.GetYaxis().SetRangeUser(-2,4)
energy.SetYTitle('Reco IHCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
timing.Draw('same')
#leg.Draw()
canvas.Draw()
#canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ihcal_reco_multi_zs_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

timing = divide_histograms(h_eT_data_ohcal, h_eT_sim1_ohcal)
energy = divide_histograms(h_eT_epos_ohcal, h_eT_sim_ohcal) 
both = divide_histograms(h_eT_ampt_ohcal, h_eT_data2_ohcal)

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.18,.55,.85,.89)
leg.AddEntry("","Run 23727 MB","")
leg.AddEntry(both,"30 ADC ZS CROSS / NO ZS","lep")
leg.AddEntry(energy,"20 ADC ZS NO CROSS / NO ZS","lep")
leg.AddEntry(timing,"30 ADC ZS NO CROSS / NO ZS","lep")
leg.SetBorderSize(0)
energy.SetLineColor(3)
energy.SetMarkerColor(3)
both.SetLineColor(1)
both.SetMarkerColor(1)
timing.SetLineColor(2)
timing.SetMarkerColor(2)
energy.SetStats(0)
both.SetStats(0)
timing.SetStats(0)
energy.GetYaxis().SetRangeUser(-2,4)
both.GetYaxis().SetRangeUser(-2,4)
timing.GetYaxis().SetRangeUser(-2,4)
energy.SetYTitle('Reco OHCal dE_{T}/d#eta Ratio')
energy.SetXTitle('#eta')
energy.Draw()
both.Draw('same')
timing.Draw('same')
#leg.Draw()
canvas.Draw()
#canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ihcal_reco_multi_zs_ratio.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB
print("10 ADC ZS cutoff rate of ihcal data processed with template fit")
print("w/ cross calib", float(h_ih_ampt_zs_rate.GetBinContent(2))/h_ih_ampt_zs_rate.GetEntries())
print("w/o cross calib", float(h_ih_data2_zs_rate.GetBinContent(2))/h_ih_data2_zs_rate.GetEntries())
print()
print("20 ADC ZS cutoff rate of ihcal data processed with template fit")
print("w/ cross calib", float(h_ih_epos_zs_rate.GetBinContent(2))/h_ih_epos_zs_rate.GetEntries())
print("w/o cross calib", float(h_ih_sim_zs_rate.GetBinContent(2))/h_ih_sim_zs_rate.GetEntries())
print()
print("30 ADC ZS cutoff rate of ihcal data processed with template fit")
print("w/ cross calib", float(h_ih_data_zs_rate.GetBinContent(2))/h_ih_data_zs_rate.GetEntries())
print("w/o cross calib", float(h_ih_sim1_zs_rate.GetBinContent(2))/h_ih_sim1_zs_rate.GetEntries())
print()
# Out:
# 10 ADC ZS cutoff rate of ihcal data processed with template fit
# w/ cross calib 0.0035238833135965114
# w/o cross calib 0.0035238833135965114
#
# 20 ADC ZS cutoff rate of ihcal data processed with template fit
# w/ cross calib 1.0365884203757848e-06
# w/o cross calib 1.0365884203757848e-06
#
# 30 ADC ZS cutoff rate of ihcal data processed with template fit
# w/ cross calib 1.672197388858776e-07
# w/o cross calib 1.672197388858776e-07

# %%
print("10 ADC ZS cutoff rate of ohcal data processed with template fit")
print("w/ cross calib", float(h_oh_ampt_zs_rate.GetBinContent(2))/h_oh_ampt_zs_rate.GetEntries())
print("w/o cross calib", float(h_oh_data2_zs_rate.GetBinContent(2))/h_oh_data2_zs_rate.GetEntries())
print()
print("20 ADC ZS cutoff rate of ohcal data processed with template fit")
print("w/ cross calib", float(h_oh_epos_zs_rate.GetBinContent(2))/h_oh_epos_zs_rate.GetEntries())
print("w/o cross calib", float(h_oh_sim_zs_rate.GetBinContent(2))/h_oh_sim_zs_rate.GetEntries())
print()
print("30 ADC ZS cutoff rate of ohcal data processed with template fit")
print("w/ cross calib", float(h_oh_data_zs_rate.GetBinContent(2))/h_oh_data_zs_rate.GetEntries())
print("w/o cross calib", float(h_oh_sim1_zs_rate.GetBinContent(2))/h_oh_sim1_zs_rate.GetEntries())
print()
# Out:
# 10 ADC ZS cutoff rate of ohcal data processed with template fit
# w/ cross calib 0.0030356302166569026
# w/o cross calib 0.0030356302166569026
#
# 20 ADC ZS cutoff rate of ohcal data processed with template fit
# w/ cross calib 1.3312372174488367e-06
# w/o cross calib 1.3312372174488367e-06
#
# 30 ADC ZS cutoff rate of ohcal data processed with template fit
# w/ cross calib 9.042857705476275e-07
# w/o cross calib 9.042857705476275e-07

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.5,.6,.85,.9)
leg.AddEntry("","Run 31521 3M events","")
leg.AddEntry(h_data1_ohcal,"NO ZS","lep")
leg.AddEntry(h_ampt_ohcal,"10 ADC ZS CC","lep")
leg.AddEntry(h_epos_ohcal,"20 ADC ZS CC","lep")
leg.AddEntry(h_data_ohcal,"30 ADC ZS CC","lep")
leg.AddEntry(h_data2_ohcal,"10 ADC ZS NO CC","lep")
leg.AddEntry(h_sim_ohcal,"20 ADC ZS NO CC","lep")
leg.AddEntry(h_sim1_ohcal,"30 ADC ZS NO CC","lep")
leg.SetBorderSize(0)
h_data_ohcal.SetStats(0)
h_data1_ohcal.SetStats(0)
h_data2_ohcal.SetStats(0)
h_sim_ohcal.SetStats(0)
h_sim1_ohcal.SetStats(0)
h_epos_ohcal.SetStats(0)
h_ampt_ohcal.SetStats(0)
h_data_ohcal.SetLineColor(7)
h_data1_ohcal.SetLineColor(1)
h_sim_ohcal.SetLineColor(6)
h_epos_ohcal.SetLineColor(2)
h_ampt_ohcal.SetLineColor(3)
h_sim1_ohcal.SetLineColor(4)
h_data_ohcal.SetMarkerColor(7)
h_data1_ohcal.SetMarkerColor(1)
h_sim_ohcal.SetMarkerColor(6)
h_epos_ohcal.SetMarkerColor(2)
h_ampt_ohcal.SetMarkerColor(3)
h_sim1_ohcal.SetMarkerColor(4)
h_data2_ohcal.SetLineColor(9)
h_data2_ohcal.SetMarkerColor(9)
h_data_ohcal.GetXaxis().SetRangeUser(-5,20)
h_data1_ohcal.GetXaxis().SetRangeUser(-5,20)
h_sim_ohcal.GetXaxis().SetRangeUser(-5,20)
h_sim1_ohcal.GetXaxis().SetRangeUser(-5,20)
h_epos_ohcal.GetXaxis().SetRangeUser(-5,20)
h_ampt_ohcal.GetXaxis().SetRangeUser(-5,20)
h_data2_ohcal.GetXaxis().SetRangeUser(-5,20)
h_data1_ohcal.SetXTitle("#SigmaE_{T,OHCal} [GeV]")
h_data_ohcal.Draw()
h_sim_ohcal.Draw('same')
h_sim1_ohcal.Draw('same')
h_epos_ohcal.Draw('same')
h_ampt_ohcal.Draw('same')
h_data2_ohcal.Draw('same')
h_data1_ohcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ohcal_totalET_pedestal_sub_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/ohcal_totalET_pedestal_sub_3M.png has been created

# %%
# data, 30 ADC CROSS CALIB
# data1, NO ZS
# epos, 20 ADC CROSS CALIB
# ampt, 10 ADC CROSS CALIB
# sim1, 30 ADC NO CROSS CALIB
# sim, 20 ADC NO CROSS CALIB
# data2, 10 ADC NO CROSS CALIB

canvas = TCanvas("canvas","",600,500)
leg = ROOT.TLegend(.5,.6,.85,.9)
leg.AddEntry("","Run 31521 3M events","")
leg.AddEntry(h_data1_ihcal,"NO ZS","lep")
leg.AddEntry(h_ampt_ihcal,"10 ADC ZS CC","lep")
leg.AddEntry(h_epos_ihcal,"20 ADC ZS CC","lep")
leg.AddEntry(h_data_ihcal,"30 ADC ZS CC","lep")
leg.AddEntry(h_data2_ihcal,"10 ADC ZS NO CC","lep")
leg.AddEntry(h_sim_ihcal,"20 ADC ZS NO CC","lep")
leg.AddEntry(h_sim1_ihcal,"30 ADC ZS NO CC","lep")
leg.SetBorderSize(0)
h_data_ihcal.SetStats(0)
h_data1_ihcal.SetStats(0)
h_data2_ihcal.SetStats(0)
h_sim_ihcal.SetStats(0)
h_sim1_ihcal.SetStats(0)
h_epos_ihcal.SetStats(0)
h_ampt_ihcal.SetStats(0)
h_data_ihcal.SetLineColor(7)
h_data1_ihcal.SetLineColor(1)
h_sim_ihcal.SetLineColor(6)
h_epos_ihcal.SetLineColor(2)
h_ampt_ihcal.SetLineColor(3)
h_sim1_ihcal.SetLineColor(4)
h_data_ihcal.SetMarkerColor(7)
h_data1_ihcal.SetMarkerColor(1)
h_sim_ihcal.SetMarkerColor(6)
h_epos_ihcal.SetMarkerColor(2)
h_ampt_ihcal.SetMarkerColor(3)
h_sim1_ihcal.SetMarkerColor(4)
h_data2_ihcal.SetLineColor(9)
h_data2_ihcal.SetMarkerColor(9)
h_data_ihcal.GetXaxis().SetRangeUser(-5,10)
h_data1_ihcal.GetXaxis().SetRangeUser(-5,10)
h_sim_ihcal.GetXaxis().SetRangeUser(-5,10)
h_sim1_ihcal.GetXaxis().SetRangeUser(-5,10)
h_epos_ihcal.GetXaxis().SetRangeUser(-5,10)
h_ampt_ihcal.GetXaxis().SetRangeUser(-5,10)
h_data2_ihcal.GetXaxis().SetRangeUser(-5,10)
h_data1_ihcal.SetXTitle("#SigmaE_{T,IHCal} [GeV]")
h_data1_ihcal.Draw()
h_sim_ihcal.Draw('same')
h_sim1_ihcal.Draw('same')
h_epos_ihcal.Draw('same')
h_ampt_ihcal.Draw('same')
h_data2_ihcal.Draw('same')
h_data_ihcal.Draw('same')
leg.Draw()
canvas.Draw()
canvas.SaveAs('/sphenix/u/egm2153/spring_2024/results_2_28/ihcal_totalET_pedestal_sub_3M.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /sphenix/u/egm2153/spring_2024/results_2_28/ihcal_totalET_pedestal_sub_3M.png has been created
